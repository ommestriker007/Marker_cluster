# %% [markdown]
# <a href="https://colab.research.google.com/github/ommestriker007/Marker_cluster/blob/main/Marker_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import leafmap

# %%
base = leafmap.Map()
# base

# %%
Odisha_transport = "https://raw.githubusercontent.com/ommestriker007/Marker_cluster/refs/heads/main/transport.csv"

# %%
base.add_points_from_xy(Odisha_transport, x = "Lat", y = "Long", layer_name = "Transport")
base
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
